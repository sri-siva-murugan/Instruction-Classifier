# %% [markdown]
# <a href="https://colab.research.google.com/github/sri-siva-murugan/Instruction-Classifier/blob/main/Instruction_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Identification & classification of instructions by analyzing POS tags**

# %%
# !pip install flair

# %%
pip install flask-ngrok

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# %%
from flair.data import Sentence
from flair.models import SequenceTagger
from flair.tokenization import SegtokSentenceSplitter

text="""Who are you? He is a boy. Why are you doing this? What am I supposed to do? How are you?"""

splitter = SegtokSentenceSplitter()
sentences = splitter.split(text)

sent = sentences
print(sent)

tagger = SequenceTagger.load("flair/pos-english")
tagger.predict(sentences)

#print(sentences)
for s in sentences:
  print(s)


#print("Instructions")
#for sentence in range(len(sentences)):
#    if(sentences[sentence][0].get_tag('pos').to_dict()['value'] == 'VB'):
#        s = str(sent[sentence])
#        low = s.find('"')
#        high = s.find('"',11)
#        print(s[low+1:high], sep="\n")
# Out:
# [Sentence: "Who are you ?"   [− Tokens: 4], Sentence: "He is a boy ."   [− Tokens: 5], Sentence: "Why are you doing this ?"   [− Tokens: 6], Sentence: "What am I supposed to do ?"   [− Tokens: 7], Sentence: "How are you ?"   [− Tokens: 4]]
# 2021-12-26 16:18:24,973 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# Sentence: "Who are you ?"   [− Tokens: 4  − Token-Labels: "Who <WP> are <VBP> you <PRP> ? <.>"]
# Sentence: "He is a boy ."   [− Tokens: 5  − Token-Labels: "He <PRP> is <VBZ> a <DT> boy <NN> . <.>"]
# Sentence: "Why are you doing this ?"   [− Tokens: 6  − Token-Labels: "Why <WRB> are <VBP> you <PRP> doing <VBG> this <DT> ? <.>"]
# Sentence: "What am I supposed to do ?"   [− Tokens: 7  − Token-Labels: "What <WP> am <VBP> I <PRP> supposed <VBN> to <TO> do <VB> ? <.>"]
# ...

# %%
# !pip install flair

# %%
#reading the csv file and identifying the instructions.

import pandas as pd 

from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("Instructions : ")
for s in sentences :
  data = Sentence(s)
  tagger.predict(data)
  # print(len(data))
  # for i in data:
  #   if (i.get_tag('pos').to_dict()['value'] == "NN"):
  #     print(s)
  print(data)
  #for word in s:
  #  if (word.get_tag('pos').to_dict()['value'] == "NN"):
  #    print(data)
  #if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
    #print(s)
# Out:
# 2021-10-30 06:28:05,577 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# Instructions :
# 9
# 6
# 5
# 6
# Do not open the fridge.
# 4
# Avoid drinking alcohol.
# 4
# Stop the car.

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

tagger = SequenceTagger.load("flair/pos-english")

def isInstruction(s):
  #print(s)
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
    return True
  for i in data:
    if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')):
      return False
    if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.get_tag('pos').to_dict()['key'] != 'must') or (i.get_tag('pos').to_dict()['key'] != 'should'))):
      return False
  ls = list(s.split(" "))
  flag = True
  pronouns = ['You', 'I', 'He', 'She', 'It', 'They']
  n = 0
  for i in data:
    if (i.get_tag('pos').to_dict()['value'] != 'VB'):
      n += 1
    else:
      break
  print("n = ", n)
  print("List: ", ls)
  for i in range(n-1):
    if (ls[i] in pronouns):
      print(i, ls[i])
      return False
  return True
  #if (ls.count())
  #for i in ls:
  #  print(i, " ")
  #print(ls)
  #print(ls.find("If"))
  #if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
  #  return True
  #return False

df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("Instructions : ")
for s in sentences :
  if (isInstruction(s)):
    print(s)
  #data = Sentence(s)
  #tagger.predict(data)
  #print(len(data))
  #print(data)
  #for i in data:
  #  if (i.get_tag('pos').to_dict()['value'] == "NN"):
  #    print(s)

# %%
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize

text="""
this is a good day.
do wake up in the morning.
don't sleep for long time.
we can meet in the park.
wait for me.
get out of here .
call you later.
kill the negativity.
search for a friend.
"""


tokenized_text = sent_tokenize(text)

for sentence in tokenized_text:
    temp = word_tokenize(sentence)
    for i in range(len(temp)):
      pos = nltk.pos_tag([temp[i]])
      print(temp[i] , "\t-\t" , pos[0][1])
    print()

# %%
#NEGATIVE INSTRUCTION CLASSIFICATION


import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter
from segtok.segmenter import split_single

df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("-----NEGATIVE INSTRUCTIONS-----")
#splitter = SegtokSentenceSplitter()
#sent = splitter.split(sentences)
for s in sentences :
  data = Sentence(s)
  tagger.predict(data)
  ls = list(s.split(" "))
  #sen = [sent for sent in split_single(s)]
  #if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
  #  print(s)
  if ((ls[0] == "Don't") and (data[2].get_tag('pos').to_dict()['value'] == 'VB')):
    print(s)
  if (((ls[0] == "Stop") or (ls[0] == "Avoid")) and (data[1].get_tag('pos').to_dict()['value'] == 'VBG')):
    print(s)
  if (ls[0] == 'Never' and data[1].get_tag('pos').to_dict()['value'] == 'VB'):
    print(s)
  #print(ls[0])
# Out:
# 2021-10-30 08:11:38,991 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# -----NEGATIVE INSTRUCTIONS-----
# Don't be afraid to get up high either especially for infrequently used supplies.
# Don't be sentimental here.
# Don't go there.
# Avoid drinking alcohol.
# Don't eat too much fats.
# Don't use your leg to pick things up.
# Never miss your breakfast.

# %%
#Experimenting NER (named entity recognition)

import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter
from segtok.segmenter import split_single

df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("-----NEGATIVE INSTRUCTIONS-----")
for s in sentences :
  # make a sentence
  sentence = Sentence(s)

  # load the NER tagger
  tagger = SequenceTagger.load('ner')

  # run NER over sentence
  tagger.predict(sentence)
  for entity in sentence.get_spans('ner'):
    print(entity)

# %%
#IDENTIFICATION OF 'INSTRUCTIONS WITH REASONS'

import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter
from segtok.segmenter import split_single

df = pd.read_csv("/content/sample_data/instructionswithreasons.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("-----INSTRUCTIONS WITH REASON-----")

#if the first word is 'if', we'll find the ',' and then check if the phrase after ',' is an instruction
#else, we look if there is an if in the sentence and then take the phrase before the ',' which precedes the 'if' 
#and check if that phrase is an instruction
for s in sentences :
  #print(s)
  i = s.index(',')
  if (s[0] == "I" and s[1] == "f"):
    st = s[i+2:]
    data = Sentence(st)
    tagger.predict(data)
    #print(data)
    if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
      print("\n-----\n" + s + "\n-----\n")
      #if (data[i+1].get_tag('pos').to_dict()['value'] == 'VB'):
      #  print(s)
  else:
    if (s.find('if', i+1) != -1):
      st = s[0:i]
      data = Sentence(st)
      tagger.predict(data)
      if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
        print("\n-----\n" + s + "\n-----\n")

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter
from segtok.segmenter import split_single

df = pd.read_csv("/content/sample_data/optionalinstructions.csv");
sentences = df['0'].tolist()

tagger = SequenceTagger.load("flair/pos-english")

print("-----OPTIONAL INSTRUCTIONS-----")

for s in sentences:
  i = s.find(" or")
  print(i)
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    #print(str1 + "||" + str2)
    data1, data2 = Sentence(str1), Sentence(str2)
    tagger.predict(data1)
    tagger.predict(data2)
    #the part of sentence before or after the word 'or' has to be an instruction
    if ((data1[0].get_tag('pos').to_dict()['value'] == 'VB') or (data2[0].get_tag('pos').to_dict()['value'] == 'VB')):
      print(s)
# Out:
# 2021-10-30 16:48:25,577 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# -----OPTIONAL INSTRUCTIONS-----
# 8
# Go right or go left.
# 11
# Use the pen or use the pencil.
# 14
# Use the pencil or pen.
# 13
# Take the book or the note.
# 16
# Ride the bicycle or the bike.
# 18
# Drink enough water or don't sweat often.
# 27
# Kill the mosquito with hand or using a mosquito repellant.
# 15
# Come home, eren or die in Liberio.
# -1
# -1
# -1
# -1
# -1
# -1
# 37
# 31
# Stop the car to attend the call or turn off the phone.

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

verb = ['VB','VBG','VBP','VBZ'] 
noun = ['NN','NNP','NNPS','NNS']

tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
    return True
  else:
    for i in data:
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')):
        return False
      if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.get_tag('pos').to_dict()['key'] != 'must') or (i.get_tag('pos').to_dict()['key'] != 'should'))):
        return False
    verb_found = 0
    noun_found = 0
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False

def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  ls = list(s.split(" "))
  #sen = [sent for sent in split_single(s)]
  #if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
  #  print(s)
  spaceIndex, notIndex = s.find(" "), s.find("not")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  #if ((ls[0] == "Don't") and (data[2].get_tag('pos').to_dict()['value'] == 'VB')):
  #  return True
  #if (((ls[0] == "Stop") or (ls[0] == "Avoid")) and (data[1].get_tag('pos').to_dict()['value'] == 'VBG')):
  #  return True
  #if (ls[0] == 'Never' and data[1].get_tag('pos').to_dict()['value'] == 'VB'):
  #  return True
  if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and isInstruction(s2)):
    return True
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  if (((ls[0] == "Stop") or (ls[0] == "Avoid")) and isInstruction(s1)):
    return True
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  return False

def isInstructionWithReason(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(',')
  if (i != -1):
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      data = Sentence(st)
      tagger.predict(data)
      #print(data)
      #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
      #  return True
        #print("\n-----\n" + s + "\n-----\n")
        #if (data[i+1].get_tag('pos').to_dict()['value'] == 'VB'):
        #  print(s)
      if (isInstruction(st)):
        return True
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        data = Sentence(st)
        tagger.predict(data)
        #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
          #print("\n-----\n" + s + "\n-----\n")
        #  return True
        if (isInstruction(st)):
          return True
  return False


def isOptionalInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(" or ")
  #print(i)
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    #print(str1 + "||" + str2)
    #data1, data2 = Sentence(str1), Sentence(str2)
    #tagger.predict(data1)
    #tagger.predict(data2)
    #the part of sentence before or after the word 'or' has to be an instruction
    #if ((data1[0].get_tag('pos').to_dict()['value'] == 'VB') or (data2[0].get_tag('pos').to_dict()['value'] == 'VB')):
    #  return True
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False


df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

print("\n-----NEGATIVE INSTRUCTIONS-----\n")
for s in sentences:
  if (isInstruction(s)):
    if (isNegativeInstruction(s)):
      print(s)
print("\n-----INSTRUCTIONS WITH REASON-----\n")
for s in sentences:
  if (isInstruction(s)):
    if (isInstructionWithReason(s)):
      print(s)
print("\n-----OPTIONAL INSTRUCTIONS-----\n")
for s in sentences:
  if (isInstruction(s)):
    if (isOptionalInstruction(s)):
      print(s)
# Out:
# 2021-11-07 14:27:32,104 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
#
# -----NEGATIVE INSTRUCTIONS-----
#
# Don't be afraid to get up high either especially for infrequently used supplies.
# Don't be sentimental here.
# Don't go there.
# Do not open the fridge.
# Avoid drinking alcohol.
# Don't eat too much fats.
# Don't use your leg to pick things up.
# Never miss your breakfast.
#
# -----INSTRUCTIONS WITH REASON-----
#
# If there is an obstruction, take another path.
# If there is a fire in the building, don't use the lift.
# If you need help, do call me.
# Study well, if you want to ace the exam.
# If you go the hotel, get me chappathis.
# If there is an obstruction, take another path.
# If there is a fire in the building, don't use the lift.
# If you need help, do call me.
# Study well, if you want to ace the exam.
# ...

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

verb = ['VB','VBG'] #present verb forms
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns

tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  else:
    # for i in data:
    #   #checks if the sentence has a past tense verb or not
    #   #if there is a past tense verb, it is not an instruction
    #   if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
    #     return False 
    #   #checks if there is a modal verb
    #   #if there is a modal verb, it has to be either must 'or' should.
    #   #if there is any other modal verb, then it is not a sentence
    #   if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.get_tag('pos').to_dict()['key'] != 'must') or (i.get_tag('pos').to_dict()['key'] != 'should'))):
    #     return False 
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return True

def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  ls = list(s.split(" "))
  spaceIndex, notIndex = s.find(" "), s.find("not")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  #we check if the first 2 words are 'Do not'. If yes, then it is a negative instruction
  if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and (ls[1][0] == 'n') and (ls[1][2] == 't') and isInstruction(s2)):
    return True
  #we check if the first word is 'Don't'. If yes, then it is a negative instruction
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  #we check if the first word is 'Stop' or 'Avoid' and the rest of the sentence is an instruction or not.
  #If yes, then it is a negative instruction
  if (((ls[0] == "Stop") or (ls[0] == "Avoid")) and isInstruction(s1)):
    return True
  #if the first word is 'Never' and the rest of the sentence is an instruction, then it is a neg instruction
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  return False

def isInstructionWithReason(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        data = Sentence(st)
        tagger.predict(data)
        #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
          #print("\n-----\n" + s + "\n-----\n")
        #  return True
        if (isInstruction(st)):
          return True
  return False


def isOptionalInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(" or ")
  #print(i)
  #we find the first index of 'or' in a sentence
  #we split the sentence into 2 sentences. Before and after 'or'.
  #if we both the sentences are instructions, then it is an optional instruction.
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False



s = "This must be done now"
if (isInstruction(s)):
  if (isNegativeInstruction(s)):
    print(i,s," - Negative instruction")
  elif (isInstructionWithReason(s)):
    print(i,s," - Instruction with reason")
  elif (isOptionalInstruction(s)):
    print(i,s," - Optional instruction")
  else:
    print(i,s," - Mandatory instruction")
# Out:
# 2021-11-08 05:28:10,930 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# 30 This must be done now  - Mandatory instruction

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

verb = ['VB','VBG'] #present verb forms
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns


tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  elif (data[0].get_tag('pos').to_dict()['value'] == 'WRB' or data[0].get_tag('pos').to_dict()['value'] == 'MD'):
    return False
  else:
    for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
        return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either must 'or' should.
      #if there is any other modal verb, then it is not a sentence
      #if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.get_tag('pos').to_dict()[] != 'must') or (i.get_tag('pos').to_dict()[#] != 'should'))):
      # return False 
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False

def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  ls = list(s.split(" "))
  spaceIndex, notIndex = s.find(" "), s.find("not")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  #we check if the first 2 words are 'Do not'. If yes, then it is a negative instruction
  if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and (ls[1][0] == 'n') and (ls[1][2] == 't') and isInstruction(s2)):
    return True
  #we check if the first word is 'Don't'. If yes, then it is a negative instruction
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  #we check if the first word is 'Stop' or 'Avoid' and the rest of the sentence is an instruction or not.
  #If yes, then it is a negative instruction
  if (((ls[0] == "Stop") or (ls[0] == "Avoid")) and isInstruction(s1)):
    return True
  #if the first word is 'Never' and the rest of the sentence is an instruction, then it is a neg instruction
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  return False

def isInstructionWithReason(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        data = Sentence(st)
        tagger.predict(data)
        #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
          #print("\n-----\n" + s + "\n-----\n")
        #  return True
        if (isInstruction(st)):
          return True
  return False


def isOptionalInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(" or ")
  #print(i)
  #we find the first index of 'or' in a sentence
  #we split the sentence into 2 sentences. Before and after 'or'.
  #if we both the sentences are instructions, then it is an optional instruction.
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False


df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()

i = 1
for s in sentences:
  if (isInstruction(s)):
    if (isNegativeInstruction(s)):
      print(i,s," - Negative instruction")
    elif (isInstructionWithReason(s)):
      print(i,s," - Instruction with reason")
    elif (isOptionalInstruction(s)):
      print(i,s," - Optional instruction")
    else:
      print(i,s," - Unclassified instruction")
    i += 1
# Out:
# 2021-11-08 05:39:51,734 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# 1 Don't be afraid to get up high either especially for infrequently used supplies.   - Negative instruction
# 2 Don't be sentimental here.   - Negative instruction
# 3 Don't go there.  - Negative instruction
# 4 Do not open the fridge.  - Negative instruction
# 5 Avoid drinking alcohol.  - Negative instruction
# 6 Stop the car.  - Unclassified instruction
# 7 Don't eat too much fats.   - Negative instruction
# 8 Cross the road in the zebra crossing.    - Unclassified instruction
# 9 Avoid direct contact with fire.   - Unclassified instruction
# 10 Hold the pen in your right hand.   - Unclassified instruction
# 11 Pick me up at 8 am.   - Unclassified instruction
# 12 Obey your parents.   - Unclassified instruction
# 13 Don't use your leg to pick things up.   - Negative instruction
# ...

# %%
#checking instruction with reason
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

verb = ['VB','VBG', 'VBZ', 'VBP'] #present verb forms
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns

tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  else:
    #for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      #if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
      #  return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either must 'or' should.
      #if there is any other modal verb, then it is not a sentence
      #if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.get_tag('pos').to_dict()[] != 'must') or (i.get_tag('pos').to_dict()[#] != 'should'))):
      # return False 
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False

def isInstructionWithReason(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        data = Sentence(st)
        tagger.predict(data)
        #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
          #print("\n-----\n" + s + "\n-----\n")
        #  return True
        if (isInstruction(st)):
          return True
  return False


df = pd.read_csv("/content/sample_data/instructionswithreasons.csv");
sentences = df['0'].tolist()

i = 1
for s in sentences:
  print(s, isInstruction(s))

  if (isInstruction(s)):
    if (isInstructionWithReason(s)):
      print(i,s," - Instruction with reason")
    i += 1
# Out:
# 2021-11-08 05:06:14,502 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# If there is an obstruction, take another path. True
# 1 If there is an obstruction, take another path.  - Instruction with reason
# If there is a fire in the building, don't use the lift. True
# 2 If there is a fire in the building, don't use the lift.  - Instruction with reason
# If you need help, do call me. True
# 3 If you need help, do call me.  - Instruction with reason
# In case of emergency, call the police. False
# Study well, if you want to ace the exam. True
# 4 Study well, if you want to ace the exam.  - Instruction with reason
# Sleep well, if you want to perform well in the tournament tomorrow. True
# If you go the hotel, get me chappathis. True
# 6 If you go the hotel, get me chappathis.  - Instruction with reason

# %%
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

#verb = ['VB','VBG', 'VBZ', 'VBP'] #present verb forms
verb = ['VB','VBG']
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns
notAllowed = ['is', 'are', 'am']
tagger = SequenceTagger.load("flair/pos-english")


# def isInstruction(s):
#   data = Sentence(s)
#   tagger.predict(data)
#   #print(data)
#   modalsPresent = []
#   if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
#     return True
#   elif ((data[0].text == 'If') or (data[0].text == 'While') or (data[0].text == 'To') or (data[0].text == 'In' and data[1].text == 'order' and data[2].text == 'to')):
#     comma = s.find(',')
#     if (comma != -1):
#       st = s[comma+2:]
#       data = Sentence(st)
#       tagger.predict(data)
#       if (isInstruction(st)):
#         return True
#       return False
#   else:
#     for i in data:
#       #checks if the sentence has a past tense verb or not
#       #if there is a past tense verb, it is not an instruction
#       if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
#         return False 
#       #checks if there is a modal verb
#       #if there is a modal verb, it has to be either must 'or' should.
#       #if there is any other modal verb, then it is not a sentence
#       if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text != 'must') and (i.text != 'should'))):
#         return False 
#       elif ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text == 'must') or (i.text == 'should'))):
#         return True
#       #if it is a VBP (Verb, non-3rd person singular present), it should not be 'am' and 'are'
#       #if it is a VBZ (Verb, 3rd person singular present), it should not be 'is' and 'are'
#       if (((i.get_tag('pos').to_dict()['value'] == 'VBZ') or (i.get_tag('pos').to_dict()['value'] == 'VBP') )and (i.text in notAllowed)):
#         return False
#     verb_found = 0
#     noun_found = 0
#     #we iterate through the sentence and check if a verb occurs before the first occurence of noun
#     #if yes, then it is a sentence. else, it is not a sentence
#     for j in range(len(data)):
#       if(data[j].get_tag('pos').to_dict()['value'] in verb):
#         verb_found = 1
#       elif(data[j].get_tag('pos').to_dict()['value'] in noun):
#         noun_found = 1
#       if (verb_found == 1 and noun_found == 0):
#         return True
#       elif (noun_found == 1 and verb_found == 0):
#         return False
#     return False

def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  elif ((data[0].text == 'If') or (data[0].text == 'While') or (data[0].text == 'To') or (data[0].text == 'In' and data[1].text == 'order' and data[2].text == 'to')):
    comma = s.find(',')
    if (comma != -1):
      st = s[comma+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
      return False
  else:
    for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
        return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either must 'or' should.
      #if there is any other modal verb, then it is not a sentence
      if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text != 'must') and (i.text != 'should'))):
        return False 
      elif ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text == 'must') or (i.text == 'should'))):
        return True
      #if it is a VBP (Verb, non-3rd person singular present), it should not be 'am' and 'are'
      #if it is a VBZ (Verb, 3rd person singular present), it should not be 'is' and 'are'
      if (((i.get_tag('pos').to_dict()['value'] == 'VBZ') or (i.get_tag('pos').to_dict()['value'] == 'VBP') )and (i.text in notAllowed)):
        return False
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False
    return False

df = pd.read_csv("/content/sample_data/sample.csv");
#sentences = df['0'].tolist()
sentences = ['To get a degree, complete college.', 'Students must follow the instructions.', 'Be fresh.', 'While you are hungry, eat the oat.', "Don't you dare kick me out."]

i = 1
for s in sentences:
  print(s, isInstruction(s))
  i += 1

# %%
#checking instruction with reason
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

verb = ['VB','VBG'] #present verb forms
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns

tagger = SequenceTagger.load("flair/pos-english")
# df = pd.read_csv("/content/sample_data/instructions2.csv");
# sentences = df['0'].tolist()

sentences = ['Do not smoke', 'This is a sentence.', 'I am a good boy.', 'Balls are hanging in the tree.', 'I would do this for you.', 'If you go the hotel, buy me chappathi or puri.', 'If I were a bird, I would fly.', 'If you want to pass the exam, you must study well.', 'Sleep well, if you want to perform well in the tournament tomorrow.']
for s in sentences:
  data = Sentence(s)
  tagger.predict(data)
  print(data)
# Out:
# 2021-11-25 13:42:55,090 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# Sentence: "Do not smoke"   [− Tokens: 3  − Token-Labels: "Do <VB> not <RB> smoke <VB>"]
# Sentence: "This is a sentence ."   [− Tokens: 5  − Token-Labels: "This <DT> is <VBZ> a <DT> sentence <NN> . <.>"]
# Sentence: "I am a good boy ."   [− Tokens: 6  − Token-Labels: "I <PRP> am <VBP> a <DT> good <JJ> boy <NN> . <.>"]
# Sentence: "Balls are hanging in the tree ."   [− Tokens: 7  − Token-Labels: "Balls <NNS> are <VBP> hanging <VBG> in <IN> the <DT> tree <NN> . <.>"]
# Sentence: "I would do this for you ."   [− Tokens: 7  − Token-Labels: "I <PRP> would <MD> do <VB> this <DT> for <IN> you <PRP> . <.>"]
# ...

# %%
###FINALIZED CODE AS OF 23/11/2021###
import pandas as pd 
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

#verb = ['VB','VBG', 'VBZ', 'VBP'] #present verb forms
verb = ['VB','VBG']
noun = ['NN','NNP','NNPS','NNS'] #singular, plural and proper nouns
notAllowed = ['is', 'are', 'am']
tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  elif ((data[0].text == 'If') or (data[0].text == 'While') or (data[0].text == 'To') or (data[0].text == 'In' and data[1].text == 'order' and data[2].text == 'to')):
    comma = s.find(',')
    if (comma != -1):
      st = s[comma+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
      return False
  else:
    for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
        return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either must 'or' should.
      #if there is any other modal verb, then it is not a sentence
      if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text != 'must') and (i.text != 'should'))):
        return False 
      elif ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text == 'must') or (i.text == 'should'))):
        return True
      #if it is a VBP (Verb, non-3rd person singular present), it should not be 'am' and 'are'
      #if it is a VBZ (Verb, 3rd person singular present), it should not be 'is' and 'are'
      if (((i.get_tag('pos').to_dict()['value'] == 'VBZ') or (i.get_tag('pos').to_dict()['value'] == 'VBP') )and (i.text in notAllowed)):
        return False
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False
    return False

def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  ls = list(s.split(" "))
  #print("List: ", ls)
  dontIndex, donotIndex = s.find(" don't "), s.find(" do not ")
  spaceIndex, notIndex = s.find(" "), s.find("not")
  mustNt, shouldNt = s.find(" mustn't "), s.find(" shouldn't ")
  mustNot, shouldNot =  s.find(" must not "), s.find(" should not ")
  mustStop, shouldStop = s.find(" must stop "), s.find(" should stop ")
  mustAvoid, shouldAvoid = s.find(" must avoid "), s.find(" should avoid ")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  # sepNot = s.find(' not ')
  # if (s.find(' not ') != -1 or s.find(" n't ")):
  #   return True
  #we check if the first 2 words are 'Do not'. If yes, then it is a negative instruction
  #if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and (ls[1][0] == 'n') and (ls[1][2] == 't') and isInstruction(s2)):
  #  print (ls[0][0], ls[0][1], ls[1][0], ls[1][2])
  if (dontIndex != -1 or donotIndex != -1):
    return True
  if ((ls[0] == "Do") and (ls[1] == "not") and isInstruction(s2)):
    #print("do not case")
    return True
  #we check if the first word is 'Don't'. If yes, then it is a negative instruction
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  #we check if the first word is 'Stop' or 'Avoid' 
  #If yes, then it is a negative instruction
  if (((ls[0] == "Stop") or (ls[0] == "Avoid"))):
    return True
  #if the first word is 'Never' and the rest of the sentence is an instruction, then it is a neg instruction
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  if ((mustNot != -1) or (shouldNot != -1) or (mustNt != -1) or (shouldNt != -1)):
    return True
  if ((mustAvoid != -1) or (shouldAvoid != -1) or (mustStop != -1) or (shouldStop != -1)):
    return True
  return False

def isOptionalInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(" or ")
  #print(i)
  #we find the first index of 'or' in a sentence
  #we split the sentence into 2 sentences. Before and after 'or'.
  #if we both the sentences are instructions, then it is an optional instruction.
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False

def isInstructionWithReason(s):
  data = Sentence(s)
  tagger.predict(data)
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        data = Sentence(st)
        tagger.predict(data)
        #if (data[0].get_tag('pos').to_dict()['value'] == 'VB'):
          #print("\n-----\n" + s + "\n-----\n")
        #  return True
        if (isInstruction(st)):
          return True
  return False

def isMandatoryInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  mustIndex = s.find('must')
  shouldIndex = s.find('should')
  if ((mustIndex != -1) or (shouldIndex != -1)):
    return True
  return False

df = pd.read_csv("/content/sample_data/sample.csv");
sentences = df['0'].tolist()
# sentences = ['Do not kill animals and birds.', 'Students must follow the instructions.', "Don't be rude.", 'While you are hungry, eat the oat.', "Don't you dare kick me out."]

i = 1
for s in sentences:
  #print(s, isInstruction(s))
  if (isInstruction(s) and isNegativeInstruction(s)):
    print(s, ' - Negative Instruction')
    i+=1
  elif (isInstruction(s) and isOptionalInstruction(s)):
    print(s, ' - Optional Instruction')
    i+=1
  elif (isInstruction(s) and isInstructionWithReason(s)):
    print(s, ' - Instruction with reason')
    i+=1
  elif (isInstruction(s) and isMandatoryInstruction(s)):
     print(s, ' - Mandatory Instruction')
     i+=1
  elif (isInstruction(s)):
    print(s, ' - Unclassified Instruction')
    i+=1
# Out:
# 2021-11-17 15:20:20,101 loading file /root/.flair/models/pos-english/a9a73f6cd878edce8a0fa518db76f441f1cc49c2525b2b4557af278ec2f0659e.121306ea62993d04cd1978398b68396931a39eb47754c8a06a87f325ea70ac63
# Don't be afraid to get up high either especially for infrequently used supplies.   - Negative Instruction
# Don't be sentimental here.   - Negative Instruction
# Don't go there.  - Negative Instruction
# Do not open the fridge.  - Negative Instruction
# Avoid drinking alcohol.  - Negative Instruction
# Stop the car.  - Negative Instruction
# I'm coming to Chennai.  - Unclassified Instruction
# Don't eat too much fats.   - Negative Instruction
# Cross the road in the zebra crossing.    - Unclassified Instruction
# Hold the pen in your right hand.  - Unclassified Instruction
# Avoid direct contact with fire.   - Negative Instruction
# You must stop behaving rude.  - Negative Instruction
# You should stop wasting time.  - Negative Instruction
# You must not smoke.  - Negative Instruction
# ...

# %%
import pandas as pd
import spacy
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter

# #Getting a paragraph input from the user
# print("Enter your message down here (END the message with a tilda '~' at the end newline ): ")

# data = ""
# while (1):
#   line = input()
#   if (line == "~"):
#     break;
#   data += line + "\n"
#@title Classification Of Instructions

Passage = "I would fly. Don't be afraid to get up high either especially for infrequently used supplies. Don't be sentimental here. Don't go there. Do not open the fridge. Avoid drinking alcohol. Stop the car. I am coming to Chennai. Don't eat too much fats. Cross the road in the zebra crossing.   Hold the pen in your right hand. Avoid direct contact with fire. You must stop behaving rude. You should stop wasting time. You must not smoke. You should avoid the habit of procastination. Never miss your breakfast. This is a sentence. Welcome to Anna University. Take a book. Write a note. If there is an obstruction, take another path. If there is a fire in the building, don't use the lift. If you need help, do call me. Study well, if you want to ace the exam. Practice hard, if you want to perform well in the tournament. If you go the hotel, get me chappathis. Go right or go left. Use the pen or use the pencil. Use the pencil or pen. Take the book or the note. Ride the bicycle or use the bike. Drink enough water or you'll be dehydrated. Kill the mosquito with hand or using a mosquito repellant. Come home, eren or die in Liberio. Pull the door. Stop the car to attend the call or turn off the phone. They are good boys. It is a pen. A ball is stuck in the tree. I was going to the hotel. You must finish this work tonight. You are a good boy. I love chappatthi. Where are you mike? Would you like to have coffee? Can you do this? Will you please close the closet? How long have you been living in India? Why are you running? What is your name? Students must respect the teachers. You must obey your elders. Everybody must follow discipline. You should have some manners in public places. Students must bring their own writing tools for examination. One must not drive a vehicle without driver's license. Stop annoying people. Smoking is injurious to health. It causes cancer. Write with a pen or use a pencil. You are who you are. How to make halwa? Take a pan. Who are you? I'm not sure who you are. Get enough sunlight each day. Exercise regularly. Take the cup and place it in the table. Do your homework now or go and play outside. " #@param {type:"string"}

print(Passage)

# Tokenising the paragraph into sentences 
tokenized_text = sent_tokenize(Passage)
df = pd.DataFrame(tokenized_text)
sentences = df[0].tolist()


verb = ['VB','VBG']
noun = ['NN','NNP','NNPS','NNS','PRP'] #singular, plural and proper nouns
notAllowed = ['is', 'are', 'am']
questions = ['WRB','WP','WP$']
tagger = SequenceTagger.load("flair/pos-english")


def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  if(data[0].get_tag('pos').to_dict()['value'] in questions): #checks if the sentence is not a question
    return False
  #Block - 1
  elif ((data[0].text == 'If') or (data[0].text == 'While') or (data[0].text == 'To') or (data[0].text == 'In' and data[1].text == 'order' and data[2].text == 'to')):
    comma = s.find(',')
    if (comma != -1):
      st = s[comma+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
      else :
        return False
  else:
    #Bock - 2
    for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
        return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either 'must' or 'should'.
      #if there is any other modal verb, then it is not a sentence
      if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text != 'must') and (i.text != 'should'))):
        return False 
      elif ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text == 'must') or (i.text == 'should'))):
        return True
      #if it is a VBP (Verb, non-3rd person singular present), it should not be 'am' and 'are'
      #if it is a VBZ (Verb, 3rd person singular present), it should not be 'is' and 'are'
      if (((i.get_tag('pos').to_dict()['value'] == 'VBZ') or (i.get_tag('pos').to_dict()['value'] == 'VBP') )and (i.text in notAllowed)):
        return False
    #Block -3
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False
    return False


print("Total number of sentences : ",len(sentences))
#Checking the sentence, whether it is a instruction 
instructions = []
i = 1
ins_count = 0
print("Instructions : ")
for s in sentences:
  if (isInstruction(s)):
    print(i,s)
    i += 1
    instructions.append(s)
    ins_count +=1
print("\nTotal Instructions : ", ins_count,"\n")


#Classification of Instruction.

#verb list
verbs = ['VB','VBG', 'VBZ', 'VBP']

#Checking whether i=the sentence is instruction or not
#By checking the first word for verb.
def is_Instruction(s):
  data = Sentence(s)
  tagger.predict(data)
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
    return True
  return False

#INSTRUCTION WITH PURPOSE

def isInstructionWithPurpose(s):
  #trying to split the sentence into 2 parts
  global g,a,b
  a = ["hello","world"]
  b = ["good","morning"]
  temp = word_tokenize(s)
  #If there is "to" at starting of the sentence
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  if (temp[0] == "To"):
      g = temp[1:]
      for j in range(len(g)):
        if (g[j] == ","):
          a = g[:j]
          b = g[j+1:]
  #If there is "in order to" at the begning of the sentence 
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  elif (temp[2] == "to"):
    g = temp[3:]
    for j in range(len(g)):
      if (g[j] == ","):
        a = g[:j]
        b = g[j+1:]
  else :
    #If there is "to" in the middle of the sentence
    #find the comma in the sentence and split 
    #the sentence before comma and after comma
    for i in range(2,len(temp)):
      if (temp[i] == "to"):
        a = temp[:i]
        b = temp[i+1:]
        break
      else :
        a = ["hello","world"]
        b = ["good","morning"]
  c = " ".join(a)
  d = " ".join(b)
  #checking whether the two sub sentences are instruction
  if (is_Instruction(c) and is_Instruction(d)):
    return True
  return False;


#INSTRUCTION IN SEQUENCE
def isInstructionInSequence(s):
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  #checking if both sub statements are instructions
  temp = word_tokenize(s)
  for i in range(len(temp)):
    if (temp[i] == ","):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
    #doing the same when we encounter a "then" or "and"
    elif (temp[i] == "then"):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
    elif (temp[i] == "and"):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
  return False;

#INSTRUCTION WITH TOOL
def isInstructionWithTool(s):
  nlp = spacy.load('en')
  sent = s
  doc=nlp(sent)
  object_count = 0;
  #counting the number of objects present in the sentence
  for tok in doc :
    if(tok.dep_ == "pobj" or tok.dep_ == "dobj" ):
      #print("object : ",tok)
      object_count += 1;
  #checking whether the object count is greater than or equal to 2
  if (object_count >= 2):
    return True
  return False


#SIMPLE INSTRUCTIONS
def isSimpleInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  verb_count = 0;
  #counting the number of verbs in the sentence
  for i in range(len(data)):
    if(data[i].get_tag('pos').to_dict()['value'] in verbs):
      verb_count += 1
  if (verb_count == 1):
    return True
  return False

#OPTIONAL INSTRUCTION
def isOptionalInstruction(s):
  i = s.find(" or ")
  #we find the first index of 'or' in a sentence
  #we split the sentence into 2 sentences. Before and after 'or'.
  #if any of the sentences are instructions, then it is an optional instruction.
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False

#INSTRUCTION WITH REASON
def isInstructionWithReason(s):
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        if (isInstruction(st)):
          return True
  return False

#MANDATORY INSTRUCTION
def isMandatoryInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  mustIndex = s.find('must')
  shouldIndex = s.find('should')
  #if must or should is present in an instruction then it is a mandatory instruction
  if ((mustIndex != -1) or (shouldIndex != -1)):
    return True
  return False

#NEGATIVE INSTRUCTION
def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  ls = list(s.split(" "))
  #print("List: ", ls)
  dontIndex, donotIndex = s.find(" don't "), s.find(" do not ")
  spaceIndex, notIndex = s.find(" "), s.find("not")
  mustNt, shouldNt = s.find(" mustn't "), s.find(" shouldn't ")
  mustNot, shouldNot =  s.find(" must not "), s.find(" should not ")
  mustStop, shouldStop = s.find(" must stop "), s.find(" should stop ")
  mustAvoid, shouldAvoid = s.find(" must avoid "), s.find(" should avoid ")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  # sepNot = s.find(' not ')
  # if (s.find(' not ') != -1 or s.find(" n't ")):
  #   return True
  #we check if the first 2 words are 'Do not'. If yes, then it is a negative instruction
  #if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and (ls[1][0] == 'n') and (ls[1][2] == 't') and isInstruction(s2)):
  #  print (ls[0][0], ls[0][1], ls[1][0], ls[1][2])
  if (dontIndex != -1 or donotIndex != -1):
    return True
  if ((ls[0] == "Do") and (ls[1] == "not") and isInstruction(s2)):
    #print("do not case")
    return True
  #we check if the first word is 'Don't'. If yes, then it is a negative instruction
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  #we check if the first word is 'Stop' or 'Avoid' 
  #If yes, then it is a negative instruction
  if (((ls[0] == "Stop") or (ls[0] == "Avoid"))):
    return True
  #if the first word is 'Never' and the rest of the sentence is an instruction, then it is a neg instruction
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  if ((mustNot != -1) or (shouldNot != -1) or (mustNt != -1) or (shouldNt != -1)):
    return True
  if ((mustAvoid != -1) or (shouldAvoid != -1) or (mustStop != -1) or (shouldStop != -1)):
    return True
  return False

i = 1;
print("Classification of Instruction : \n")
for s in instructions:
  if (isNegativeInstruction(s)):
   print(i,s, " - Negative Instruction.")
  elif (isInstructionWithPurpose(s)):
   print(i,s," - Instruction With Purpose.")
  elif(isInstructionInSequence(s)):
   print(i,s, " - Instruction In Sequence.")
  elif (isOptionalInstruction(s)):
   print(i,s, ' - Optional Instruction.')
  elif (isInstructionWithReason(s)):
   print(i,s, ' - Instruction with reason.')
  elif (isMandatoryInstruction(s)):
   print(i,s, " - Mandatory Instruction.")
  elif(isInstructionWithTool(s)):
   print(i,s," - Instruction With Tool.")
  elif(isSimpleInstruction(s)):
   print(i,s," - Simple Instruction.")
  else:
   print(i,s," - Unclassified Instruction.")
  i += 1
# Out:
# I would fly. Don't be afraid to get up high either especially for infrequently used supplies. Don't be sentimental here. Don't go there. Do not open the fridge. Avoid drinking alcohol. Stop the car. I am coming to Chennai. Don't eat too much fats. Cross the road in the zebra crossing.   Hold the pen in your right hand. Avoid direct contact with fire. You must stop behaving rude. You should stop wasting time. You must not smoke. You should avoid the habit of procastination. Never miss your breakfast. This is a sentence. Welcome to Anna University. Take a book. Write a note. If there is an obstruction, take another path. If there is a fire in the building, don't use the lift. If you need help, do call me. Study well, if you want to ace the exam. Practice hard, if you want to perform well in the tournament. If you go the hotel, get me chappathis. Go right or go left. Use the pen or use the pencil. Use the pencil or pen. Take the book or the note. Ride the bicycle or use the bike. Drink 
# ...

# %%
cd /content/drive/MyDrive/Colab Notebooks/data
# Out:
# /content/drive/MyDrive/Colab Notebooks/data

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, request, render_template
import numpy as np
import pandas as pd
import spacy
import nltk
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from flair.data import Sentence 
from flair.models import SequenceTagger  
from flair.tokenization import SegtokSentenceSplitter
verb = ['VB','VBG']
noun = ['NN','NNP','NNPS','NNS','PRP'] #singular, plural and proper nouns
notAllowed = ['is', 'are', 'am']
questions = ['WRB','WP','WP$']
tagger = SequenceTagger.load("flair/pos-english")

def isInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  modalsPresent = []
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'): #checks if the first word is a verb or not
    return True
  if(data[0].get_tag('pos').to_dict()['value'] in questions): #checks if the sentence is not a question
    return False
  #Block - 1
  elif ((data[0].text == 'If') or (data[0].text == 'While') or (data[0].text == 'To') or (data[0].text == 'In' and data[1].text == 'order' and data[2].text == 'to')):
    comma = s.find(',')
    if (comma != -1):
      st = s[comma+2:]
      data = Sentence(st)
      tagger.predict(data)
      if (isInstruction(st)):
        return True
      else :
        return False
  else:
    #Bock - 2
    for i in data:
      #checks if the sentence has a past tense verb or not
      #if there is a past tense verb, it is not an instruction
      if ((i.get_tag('pos').to_dict()['value'] == 'VBN') or (i.get_tag('pos').to_dict()['value'] == 'VBD')): 
        return False 
      #checks if there is a modal verb
      #if there is a modal verb, it has to be either 'must' or 'should'.
      #if there is any other modal verb, then it is not a sentence
      if ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text != 'must') and (i.text != 'should'))):
        return False 
      elif ((i.get_tag('pos').to_dict()['value'] == 'MD') and ((i.text == 'must') or (i.text == 'should'))):
        return True
      #if it is a VBP (Verb, non-3rd person singular present), it should not be 'am' and 'are'
      #if it is a VBZ (Verb, 3rd person singular present), it should not be 'is' and 'are'
      if (((i.get_tag('pos').to_dict()['value'] == 'VBZ') or (i.get_tag('pos').to_dict()['value'] == 'VBP') )and (i.text in notAllowed)):
        return False
    #Block -3
    verb_found = 0
    noun_found = 0
    #we iterate through the sentence and check if a verb occurs before the first occurence of noun
    #if yes, then it is a sentence. else, it is not a sentence
    for j in range(len(data)):
      if(data[j].get_tag('pos').to_dict()['value'] in verb):
        verb_found = 1
      elif(data[j].get_tag('pos').to_dict()['value'] in noun):
        noun_found = 1
      if (verb_found == 1 and noun_found == 0):
        return True
      elif (noun_found == 1 and verb_found == 0):
        return False
    return False


#Classification of Instruction.

#verb list
verbs = ['VB','VBG', 'VBZ', 'VBP']

#Checking whether i=the sentence is instruction or not
#By checking the first word for verb.
def is_Instruction(s):
  data = Sentence(s)
  tagger.predict(data)
  if(data[0].get_tag('pos').to_dict()['value'] == 'VB'):
    return True
  return False

#INSTRUCTION WITH PURPOSE

def isInstructionWithPurpose(s):
  #trying to split the sentence into 2 parts
  global g,a,b
  a = ["hello","world"]
  b = ["good","morning"]
  temp = word_tokenize(s)
  #If there is "to" at starting of the sentence
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  if (temp[0] == "To"):
      g = temp[1:]
      for j in range(len(g)):
        if (g[j] == ","):
          a = g[:j]
          b = g[j+1:]
  #If there is "in order to" at the begning of the sentence 
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  elif (temp[2] == "to"):
    g = temp[3:]
    for j in range(len(g)):
      if (g[j] == ","):
        a = g[:j]
        b = g[j+1:]
  else :
    #If there is "to" in the middle of the sentence
    #find the comma in the sentence and split 
    #the sentence before comma and after comma
    for i in range(2,len(temp)):
      if (temp[i] == "to"):
        a = temp[:i]
        b = temp[i+1:]
        break
      else :
        a = ["hello","world"]
        b = ["good","morning"]
  c = " ".join(a)
  d = " ".join(b)
  #checking whether the two sub sentences are instruction
  if (is_Instruction(c) and is_Instruction(d)):
    return True
  return False;


#INSTRUCTION IN SEQUENCE
def isInstructionInSequence(s):
  #find the comma in the sentence and split 
  #the sentence before comma and after comma
  #checking if both sub statements are instructions
  temp = word_tokenize(s)
  for i in range(len(temp)):
    if (temp[i] == ","):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
    #doing the same when we encounter a "then" or "and"
    elif (temp[i] == "then"):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
    elif (temp[i] == "and"):
      a = temp[:i]
      b = temp[i+1:]
      c = " ".join(a)
      d = " ".join(b)
      if (is_Instruction(c) and is_Instruction(d)):
        return True
  return False;

#INSTRUCTION WITH TOOL
def isInstructionWithTool(s):
  nlp = spacy.load('en')
  sent = s
  doc=nlp(sent)
  object_count = 0;
  #counting the number of objects present in the sentence
  for tok in doc :
    if(tok.dep_ == "pobj" or tok.dep_ == "dobj" ):
      #print("object : ",tok)
      object_count += 1;
  #checking whether the object count is greater than or equal to 2
  if (object_count >= 2):
    return True
  return False


#SIMPLE INSTRUCTIONS
def isSimpleInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  verb_count = 0;
  #counting the number of verbs in the sentence
  for i in range(len(data)):
    if(data[i].get_tag('pos').to_dict()['value'] in verbs):
      verb_count += 1
  if (verb_count == 1):
    return True
  return False

#OPTIONAL INSTRUCTION
def isOptionalInstruction(s):
  i = s.find(" or ")
  #we find the first index of 'or' in a sentence
  #we split the sentence into 2 sentences. Before and after 'or'.
  #if any of the sentences are instructions, then it is an optional instruction.
  if (i != -1):
    str1, str2 = s[0:i], s[i+2:]
    if (isInstruction(str1) or isInstruction(str2)):
      return True
    return False

#INSTRUCTION WITH REASON
def isInstructionWithReason(s):
  i = s.find(',')
  if (i != -1):
    #if the first word is 'If' and we find the first index of ','
    #if the sentence after the comma is a instruction, then it is an instruction with reason
    if (s[0] == "I" and s[1] == "f"):
      st = s[i+2:]
      if (isInstruction(st)):
        return True
    #if the first word is not 'If', we find the first index of 'if' and
    #check if the sentence before the comma preceding the 'if' is an instruction or not
    #Example: Study well, if you want to ace the exams.
    else:
      if (s.find('if', i+1) != -1):
        st = s[0:i]
        if (isInstruction(st)):
          return True
  return False

#MANDATORY INSTRUCTION
def isMandatoryInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  mustIndex = s.find('must')
  shouldIndex = s.find('should')
  #if must or should is present in an instruction then it is a mandatory instruction
  if ((mustIndex != -1) or (shouldIndex != -1)):
    return True
  return False

#NEGATIVE INSTRUCTION
def isNegativeInstruction(s):
  data = Sentence(s)
  tagger.predict(data)
  #print(data)
  ls = list(s.split(" "))
  #print("List: ", ls)
  dontIndex, donotIndex = s.find(" don't "), s.find(" do not ")
  spaceIndex, notIndex = s.find(" "), s.find("not")
  mustNt, shouldNt = s.find(" mustn't "), s.find(" shouldn't ")
  mustNot, shouldNot =  s.find(" must not "), s.find(" should not ")
  mustStop, shouldStop = s.find(" must stop "), s.find(" should stop ")
  mustAvoid, shouldAvoid = s.find(" must avoid "), s.find(" should avoid ")
  s1 = s[spaceIndex+1:]
  s2 = s[notIndex+3:]
  # sepNot = s.find(' not ')
  # if (s.find(' not ') != -1 or s.find(" n't ")):
  #   return True
  #we check if the first 2 words are 'Do not'. If yes, then it is a negative instruction
  #if ((ls[0][0] == 'D') and (ls[0][1] == 'o') and (ls[1][0] == 'n') and (ls[1][2] == 't') and isInstruction(s2)):
  #  print (ls[0][0], ls[0][1], ls[1][0], ls[1][2])
  if (dontIndex != -1 or donotIndex != -1):
    return True
  if ((ls[0] == "Do") and (ls[1] == "not") and isInstruction(s2)):
    print("do not case")
    return True
  #we check if the first word is 'Don't'. If yes, then it is a negative instruction
  if ((ls[0] == "Don't") and isInstruction(s1)):
    return True
  #we check if the first word is 'Stop' or 'Avoid' 
  #If yes, then it is a negative instruction
  if (((ls[0] == "Stop") or (ls[0] == "Avoid"))):
    return True
  #if the first word is 'Never' and the rest of the sentence is an instruction, then it is a neg instruction
  if (ls[0] == 'Never' and isInstruction(s1)):
    return True
  if ((mustNot != -1) or (shouldNot != -1) or (mustNt != -1) or (shouldNt != -1)):
    return True
  if ((mustAvoid != -1) or (shouldAvoid != -1) or (mustStop != -1) or (shouldStop != -1)):
    return True
  return False

# %%
app = Flask(__name__)
run_with_ngrok(app)

@app.route('/')
def home():
  return render_template('index.html')

@app.route('/instructionclassification', methods=['POST'])
def instructionclassification():
  inp = [x for x in request.form.values()]
  print('inp[0]\n')
  print(inp[0])

  # Tokenising the paragraph into sentences 
  tokenized_text = sent_tokenize(inp[0])
  print('tokenized text\n')
  print(tokenized_text)
  df = pd.DataFrame(tokenized_text)
  sentences = df[0].tolist()
  instructionsList = []
  for i in sentences:
    if (isInstruction(i)):
      instructionsList.append(i)
  print("instruction list")
  print(instructionsList)
  #-----#
  n = 1
  instructions = "NEGATIVE INSTRUCTIONS:\n--------------------------------------\n"
  for i in instructionsList:
    if (isNegativeInstruction(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
  #-----#
  n = 1
  instructions += "\n--------------------------------------\nINSTRUCTIONS WITH PURPOSE:\n--------------------------------------\n"
  for i in instructionsList:
    if (isInstructionWithPurpose(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nINSTRUCTIONS IN SEQUENCE:\n--------------------------------------\n"
  for i in instructionsList:
    if (isInstructionInSequence(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nOPTIONAL INSTRUCTIONS:\n--------------------------------------\n"
  for i in instructionsList:
    if (isOptionalInstruction(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nINSTRUCTIONS WITH REASON:\n--------------------------------------\n"
  for i in instructionsList:
    if (isInstructionWithReason(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nMANDATORY INSTRUCTIONS:\n--------------------------------------\n"
  for i in instructionsList:
    if (isMandatoryInstruction(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nINSTRUCTIONS WITH TOOL:\n--------------------------------------\n"
  for i in instructionsList:
    if (isInstructionWithTool(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  n = 1
  instructions += "\n--------------------------------------\nSIMPLE INSTRUCTIONS:\n--------------------------------------\n"
  for i in instructionsList:
    if (isSimpleInstruction(i)):
      instructions += str(n) + '. ' + i + '\n'
      n += 1
      #instructionsList.remove(i)
  # #-----#
  # if (len(instructionsList) != 0):
  #   n=1
  #   instructions += "UNCLASSIFIED INSTRUCTIONS:\n"
  #   for i in instructionsList:
  #     instructions += str(n) + '. ' + i + '\n'
  #     n += 1
  #     #instructionsList.remove(i)
  # #-----#
  # # for i in sentences:
  # #   if (isInstruction(i) and isNegativeInstruction(i)):
  # #     instructions += i + '\n'
  # # for i in sentences:

  return render_template('index.html', outp=instructions)

app.run()
